# %%
from py_neuromodulation import nm_IO
import os
import pandas as pd
from bids import BIDSLayout
import numpy as np



# read Berlin sub 008 till 012
PATH_BIDS = r"C:\Users\ICN_admin\Documents\Datasets\Berlin_new"
layout = BIDSLayout(PATH_BIDS)

run_files_Berlin = layout.get(
    task=["SelfpacedRotationR", "SelfpacedRotationL", "SelfpacedForceWheel"],
    extension=".vhdr",
)
# Out:
# c:\Users\ICN_admin\Anaconda3\envs\pn_env\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
run_files_Berlin[-1]
# Out:
# <BIDSFile filename='C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-014\ses-EcogLfpMedOn01\ieeg\sub-014_ses-EcogLfpMedOn01_task-SelfpacedRotationL_acq-StimOnB_run-1_ieeg.vhdr'>

# %%
raw_arr, data, sfreq, ln, coord_list, coord_names = nm_IO.read_BIDS_data(run_files_Berlin[-1], PATH_BIDS)
# Out:
# Extracting parameters from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-014\ses-EcogLfpMedOn01\ieeg\sub-014_ses-EcogLfpMedOn01_task-SelfpacedRotationL_acq-StimOnB_run-1_ieeg.vhdr...
# Setting channel info structure...
# Reading channel info from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-014\ses-EcogLfpMedOn01\ieeg\sub-014_ses-EcogLfpMedOn01_task-SelfpacedRotationL_acq-StimOnB_run-1_channels.tsv.
# Reading electrode coords from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-014\ses-EcogLfpMedOn01\ieeg\sub-014_ses-EcogLfpMedOn01_space-MNI152NLin2009bAsym_electrodes.tsv.

# %%
from matplotlib import pyplot as plt
plt.plot(data[-1,:])

# %%
run_files_Berlin[-5:]
# Out:
# [<BIDSFile filename='C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-012\ses-EcogLfpMedOn02\ieeg\sub-012_ses-EcogLfpMedOn02_task-SelfpacedRotationL_acq-StimOff_run-1_ieeg.vhdr'>,
#  <BIDSFile filename='C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-013\ses-EcogLfpMedOff01\ieeg\sub-013_ses-EcogLfpMedOff01_task-SelfpacedRotationL_acq-StimOff_run-1_ieeg.vhdr'>,
#  <BIDSFile filename='C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-013\ses-EcogLfpMedOn02\ieeg\sub-013_ses-EcogLfpMedOn02_task-SelfpacedRotationL_acq-StimOff_run-1_ieeg.vhdr'>,
#  <BIDSFile filename='C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-014\ses-EcogLfpMedOff01\ieeg\sub-014_ses-EcogLfpMedOff01_task-SelfpacedRotationL_acq-StimOff_run-1_ieeg.vhdr'>,
#  <BIDSFile filename='C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-014\ses-EcogLfpMedOn01\ieeg\sub-014_ses-EcogLfpMedOn01_task-SelfpacedRotationL_acq-StimOff_run-1_ieeg.vhdr'>,
#  <BIDSFile filename='C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-014\ses-EcogLfpMedOn01\ieeg\sub-014_ses-EcogLfpMedOn01_task-SelfpacedRotationL_acq-StimOnB_run-1_ieeg.vhdr'>]

# %%
run_files_Berlin = list(
    np.array([f.path for f in run_files_Berlin[-5:]])
)  # from for sub013 and sub014

# %%
run_files_Berlin
# Out:
# ['C:\\Users\\ICN_admin\\Documents\\Datasets\\Berlin_new\\sub-013\\ses-EcogLfpMedOff01\\ieeg\\sub-013_ses-EcogLfpMedOff01_task-SelfpacedRotationL_acq-StimOff_run-1_ieeg.vhdr',
#  'C:\\Users\\ICN_admin\\Documents\\Datasets\\Berlin_new\\sub-013\\ses-EcogLfpMedOn02\\ieeg\\sub-013_ses-EcogLfpMedOn02_task-SelfpacedRotationL_acq-StimOff_run-1_ieeg.vhdr',
#  'C:\\Users\\ICN_admin\\Documents\\Datasets\\Berlin_new\\sub-014\\ses-EcogLfpMedOff01\\ieeg\\sub-014_ses-EcogLfpMedOff01_task-SelfpacedRotationL_acq-StimOff_run-1_ieeg.vhdr',
#  'C:\\Users\\ICN_admin\\Documents\\Datasets\\Berlin_new\\sub-014\\ses-EcogLfpMedOn01\\ieeg\\sub-014_ses-EcogLfpMedOn01_task-SelfpacedRotationL_acq-StimOff_run-1_ieeg.vhdr',
#  'C:\\Users\\ICN_admin\\Documents\\Datasets\\Berlin_new\\sub-014\\ses-EcogLfpMedOn01\\ieeg\\sub-014_ses-EcogLfpMedOn01_task-SelfpacedRotationL_acq-StimOnB_run-1_ieeg.vhdr']

# %%
coord_list_l = []
for run_file in run_files_Berlin:
    _, _, _, _, coord_list, coord_names = nm_IO.read_BIDS_data(run_file, PATH_BIDS)
    coord_list_l.append(coord_list)
# Out:
# Extracting parameters from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-013\ses-EcogLfpMedOff01\ieeg\sub-013_ses-EcogLfpMedOff01_task-SelfpacedRotationL_acq-StimOff_run-1_ieeg.vhdr...
# Setting channel info structure...
# Reading events from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-013\ses-EcogLfpMedOff01\ieeg\sub-013_ses-EcogLfpMedOff01_task-SelfpacedRotationL_acq-StimOff_run-1_events.tsv.
# Reading channel info from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-013\ses-EcogLfpMedOff01\ieeg\sub-013_ses-EcogLfpMedOff01_task-SelfpacedRotationL_acq-StimOff_run-1_channels.tsv.
# Reading electrode coords from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-013\ses-EcogLfpMedOff01\ieeg\sub-013_ses-EcogLfpMedOff01_space-MNI152NLin2009bAsym_electrodes.tsv.
# Extracting parameters from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-013\ses-EcogLfpMedOn02\ieeg\sub-013_ses-EcogLfpMedOn02_task-SelfpacedRotationL_acq-StimOff_run-1_ieeg.vhdr...
# Setting channel info structure...
# Reading events from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-013\ses-EcogLfpMedOn02\ieeg\sub-013_ses-EcogLfpMedOn02_task-SelfpacedRotationL_acq-StimOff_run-1_events.tsv.
# Reading channel info from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-013\ses-EcogLfpMedOn02\ieeg\sub-013_ses-EcogLfpMedOn02_task-SelfpacedRotationL_acq-StimOff_run-1_channels.tsv.
# Reading electrode coords from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-013\ses-EcogLfpMedOn02\ieeg\sub-013_ses-EcogLfpMedOn02_space-MNI152NLin2009bAsym_electrodes.tsv.
# Extracting parameters from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-014\ses-EcogLfpMedOff01\ieeg\sub-014_ses-EcogLfpMedOff01_task-SelfpacedRotationL_acq-StimOff_run-1_ieeg.vhdr...
# Setting channel info structure...
# Reading events from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-014\ses-EcogLfpMedOff01\ieeg\sub-014_ses-EcogLfpMedOff01_task-SelfpacedRotationL_acq-StimOff_run-1_events.tsv.
# Reading channel info from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-014\ses-EcogLfpMedOff01\ieeg\sub-014_ses-EcogLfpMedOff01_task-SelfpacedRotationL_acq-StimOff_run-1_channels.tsv.
# Reading electrode coords from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-014\ses-EcogLfpMedOff01\ieeg\sub-014_ses-EcogLfpMedOff01_space-MNI152NLin2009bAsym_electrodes.tsv.
# Extracting parameters from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-014\ses-EcogLfpMedOn01\ieeg\sub-014_ses-EcogLfpMedOn01_task-SelfpacedRotationL_acq-StimOff_run-1_ieeg.vhdr...
# Setting channel info structure...
# Reading events from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-014\ses-EcogLfpMedOn01\ieeg\sub-014_ses-EcogLfpMedOn01_task-SelfpacedRotationL_acq-StimOff_run-1_events.tsv.
# Reading channel info from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-014\ses-EcogLfpMedOn01\ieeg\sub-014_ses-EcogLfpMedOn01_task-SelfpacedRotationL_acq-StimOff_run-1_channels.tsv.
# Reading electrode coords from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-014\ses-EcogLfpMedOn01\ieeg\sub-014_ses-EcogLfpMedOn01_space-MNI152NLin2009bAsym_electrodes.tsv.
# Extracting parameters from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-014\ses-EcogLfpMedOn01\ieeg\sub-014_ses-EcogLfpMedOn01_task-SelfpacedRotationL_acq-StimOnB_run-1_ieeg.vhdr...
# Setting channel info structure...
# Reading channel info from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-014\ses-EcogLfpMedOn01\ieeg\sub-014_ses-EcogLfpMedOn01_task-SelfpacedRotationL_acq-StimOnB_run-1_channels.tsv.
# Reading electrode coords from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-014\ses-EcogLfpMedOn01\ieeg\sub-014_ses-EcogLfpMedOn01_space-MNI152NLin2009bAsym_electrodes.tsv.

# %%
df_008_012 = pd.read_csv("berlin_electrodes_008_till_012.csv", dtype={'sub': str})

# %%
df_008_012
# Out:
#     Unnamed: 0               ch     x     y      z  sub
# 0            0  ECOG_L_1_SMC_AT -17.5 -60.5  75.50  008
# 1            1  ECOG_L_2_SMC_AT -21.0 -51.5  79.55  008
# 2            2  ECOG_L_3_SMC_AT -24.5 -41.0  81.00  008
# 3            3  ECOG_L_4_SMC_AT -26.5 -30.0  81.00  008
# 4            4  ECOG_L_5_SMC_AT -28.5 -19.0  80.50  008
# 5            5  ECOG_L_6_SMC_AT -30.0  -8.5  78.00  008
# 6            6  ECOG_L_1_SMC_AT -39.0 -35.5  73.00  009
# 7            7  ECOG_L_2_SMC_AT -38.5 -24.5  71.00  009
# 8            8  ECOG_L_3_SMC_AT -38.0 -15.0  68.00  009
# 9            9  ECOG_L_4_SMC_AT -36.5  -6.5  65.50  009
# 10          10  ECOG_L_5_SMC_AT -34.0   5.0  62.50  009
# 11          11  ECOG_L_6_SMC_AT -33.5  16.0  59.00  009
# 12          12  ECOG_R_1_SMC_AT  17.5 -60.0  73.50  010
# 13          13  ECOG_R_2_SMC_AT  22.5 -52.0  77.50  010
# 14          14  ECOG_R_3_SMC_AT  26.5 -41.5  79.00  010
# 15          15  ECOG_R_4_SMC_AT  30.0 -32.0  78.00  010
# 16          16  ECOG_R_5_SMC_AT  34.0 -22.0  75.00  010
# 17          17  ECOG_R_6_SMC_AT  36.0 -12.5  71.50  010
# 18          18  ECOG_R_1_SMC_AT  61.5 -44.5  50.00  011
# 19          19  ECOG_R_2_SMC_AT  59.5 -34.5  53.50  011
# 20          20  ECOG_R_3_SMC_AT  56.0 -25.5  56.00  011
# 21          21  ECOG_R_4_SMC_AT  51.5 -16.5  58.00  011
# 22          22  ECOG_R_5_SMC_AT  48.0  -7.0  59.00  011
# 23          23  ECOG_R_6_SMC_AT  43.0   1.5  60.00  011
# 24          24  ECOG_R_1_SMC_AT  41.0 -19.5  68.50  012
# 25          25  ECOG_R_2_SMC_AT  38.0  -8.0  65.50  012
# 26          26  ECOG_R_3_SMC_AT  36.0   2.0  63.00  012
# 27          27  ECOG_R_4_SMC_AT  33.5  12.5  62.00  012
# 28          28  ECOG_R_5_SMC_AT  32.0  24.0  63.00  012

# %%
run_files_Berlin[1:3]
# Out:
# ['C:\\Users\\ICN_admin\\Documents\\Datasets\\Berlin_new\\sub-013\\ses-EcogLfpMedOn02\\ieeg\\sub-013_ses-EcogLfpMedOn02_task-SelfpacedRotationL_acq-StimOff_run-1_ieeg.vhdr',
#  'C:\\Users\\ICN_admin\\Documents\\Datasets\\Berlin_new\\sub-014\\ses-EcogLfpMedOff01\\ieeg\\sub-014_ses-EcogLfpMedOff01_task-SelfpacedRotationL_acq-StimOff_run-1_ieeg.vhdr']

# %%
df = pd.DataFrame()
for run_file in run_files_Berlin[1:3]:
    _, _, _, _, coord_list, coord_names = nm_IO.read_BIDS_data(run_file, PATH_BIDS)
    for idx, coord_name in enumerate(coord_names):
        if "ECOG" in coord_name:
            d = {}
            d["ch"] = coord_name
            d["x"] = coord_list[idx][0] * 1000
            d["y"] = coord_list[idx][1] * 1000
            d["z"] = coord_list[idx][2] * 1000
            d["sub"] = os.path.basename(run_file)[4:7]
            df = df.append(d, ignore_index=True)
#df.drop(29)
# Out:
# Extracting parameters from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-013\ses-EcogLfpMedOn02\ieeg\sub-013_ses-EcogLfpMedOn02_task-SelfpacedRotationL_acq-StimOff_run-1_ieeg.vhdr...
# Setting channel info structure...
# Reading events from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-013\ses-EcogLfpMedOn02\ieeg\sub-013_ses-EcogLfpMedOn02_task-SelfpacedRotationL_acq-StimOff_run-1_events.tsv.
# Reading channel info from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-013\ses-EcogLfpMedOn02\ieeg\sub-013_ses-EcogLfpMedOn02_task-SelfpacedRotationL_acq-StimOff_run-1_channels.tsv.
# Reading electrode coords from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-013\ses-EcogLfpMedOn02\ieeg\sub-013_ses-EcogLfpMedOn02_space-MNI152NLin2009bAsym_electrodes.tsv.
# Extracting parameters from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-014\ses-EcogLfpMedOff01\ieeg\sub-014_ses-EcogLfpMedOff01_task-SelfpacedRotationL_acq-StimOff_run-1_ieeg.vhdr...
# Setting channel info structure...
# Reading events from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-014\ses-EcogLfpMedOff01\ieeg\sub-014_ses-EcogLfpMedOff01_task-SelfpacedRotationL_acq-StimOff_run-1_events.tsv.
# Reading channel info from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-014\ses-EcogLfpMedOff01\ieeg\sub-014_ses-EcogLfpMedOff01_task-SelfpacedRotationL_acq-StimOff_run-1_channels.tsv.
# Reading electrode coords from C:\Users\ICN_admin\Documents\Datasets\Berlin_new\sub-014\ses-EcogLfpMedOff01\ieeg\sub-014_ses-EcogLfpMedOff01_space-MNI152NLin2009bAsym_electrodes.tsv.

# %%
d
# Out:
# {'ch': 'ECOG_R_06_SMC_AT', 'x': 45.0, 'y': -9.5, 'z': 67.0, 'sub': '014'}

# %%
df_008_012
# Out:
#     Unnamed: 0               ch     x     y      z  sub
# 0            0  ECOG_L_1_SMC_AT -17.5 -60.5  75.50  008
# 1            1  ECOG_L_2_SMC_AT -21.0 -51.5  79.55  008
# 2            2  ECOG_L_3_SMC_AT -24.5 -41.0  81.00  008
# 3            3  ECOG_L_4_SMC_AT -26.5 -30.0  81.00  008
# 4            4  ECOG_L_5_SMC_AT -28.5 -19.0  80.50  008
# 5            5  ECOG_L_6_SMC_AT -30.0  -8.5  78.00  008
# 6            6  ECOG_L_1_SMC_AT -39.0 -35.5  73.00  009
# 7            7  ECOG_L_2_SMC_AT -38.5 -24.5  71.00  009
# 8            8  ECOG_L_3_SMC_AT -38.0 -15.0  68.00  009
# 9            9  ECOG_L_4_SMC_AT -36.5  -6.5  65.50  009
# 10          10  ECOG_L_5_SMC_AT -34.0   5.0  62.50  009
# 11          11  ECOG_L_6_SMC_AT -33.5  16.0  59.00  009
# 12          12  ECOG_R_1_SMC_AT  17.5 -60.0  73.50  010
# 13          13  ECOG_R_2_SMC_AT  22.5 -52.0  77.50  010
# 14          14  ECOG_R_3_SMC_AT  26.5 -41.5  79.00  010
# 15          15  ECOG_R_4_SMC_AT  30.0 -32.0  78.00  010
# 16          16  ECOG_R_5_SMC_AT  34.0 -22.0  75.00  010
# 17          17  ECOG_R_6_SMC_AT  36.0 -12.5  71.50  010
# 18          18  ECOG_R_1_SMC_AT  61.5 -44.5  50.00  011
# 19          19  ECOG_R_2_SMC_AT  59.5 -34.5  53.50  011
# 20          20  ECOG_R_3_SMC_AT  56.0 -25.5  56.00  011
# 21          21  ECOG_R_4_SMC_AT  51.5 -16.5  58.00  011
# 22          22  ECOG_R_5_SMC_AT  48.0  -7.0  59.00  011
# 23          23  ECOG_R_6_SMC_AT  43.0   1.5  60.00  011
# 24          24  ECOG_R_1_SMC_AT  41.0 -19.5  68.50  012
# 25          25  ECOG_R_2_SMC_AT  38.0  -8.0  65.50  012
# 26          26  ECOG_R_3_SMC_AT  36.0   2.0  63.00  012
# 27          27  ECOG_R_4_SMC_AT  33.5  12.5  62.00  012
# 28          28  ECOG_R_5_SMC_AT  32.0  24.0  63.00  012

# %%
pd.concat([df_008_012.reset_index(), df.iloc[6:].reset_index()]).drop(columns=["Unnamed: 0", "index"]).to_csv("berlin_coordinates_008_till_014.csv")

# %%
pd.concat([df.iloc[6:], df_008_012]).drop(columns="Unnamed: 0").sort_index().to_csv("berlin_coordinates_008_till_014.csv")

# %%
df.to_csv("berlin_electrodes.tsv")
# read coords Washington

PATH_DATA = (
    r"C:\Users\ICN_admin\Documents\Datasets\Data Kai Miller\motor_basic\data"
)
run_files_Washington = [
    os.path.join(PATH_DATA, f) for f in os.listdir(PATH_DATA) if "_mot_t_h" in f
]

l_ = []

for PATH_RUN in run_files_Washington:
    RUN_NAME = os.path.basename(PATH_RUN[:-4])
    sub_name = RUN_NAME[:2]
    electrodes = (
        nm_IO.loadmat(
            os.path.join(
                r"C:\Users\ICN_admin\Documents\Datasets\Data Kai Miller\motor_basic\transform_mni",
                sub_name + "_electrodes.mat",
            )
        )["mni_coord"]
        / 1000
    )  # transform into m
    ch_names = [f"ECOG_{i}" for i in range(electrodes.shape[0])]
    df = pd.DataFrame()
    df["ch"] = ch_names
    df["x"] = electrodes[:, 0] * 1000
    df["y"] = electrodes[:, 1] * 1000
    df["z"] = electrodes[:, 2] * 1000
    df["sub"] = sub_name
    l_.append(df)
pd.concat(l_).to_csv("sub_13_14_electrodes.csv")
